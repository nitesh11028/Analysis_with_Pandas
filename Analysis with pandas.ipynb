# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('loandata.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
# 5  LP001259    Male     Yes          1      Graduate           Yes
# 6  LP002345    Male     Yes          0      Graduate            No
# 7  LP002717    Male     Yes          0      Graduate            No
# 8  LP001030    Male     Yes          2      Graduate            No
# 9  LP001267  Female     Yes          2      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# ...

# %%
df1 = df[df['ApplicantIncome']<2000]
df1
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001722    Male     Yes          0      Graduate            No
# 1   LP002502  Female     Yes          2  Not Graduate           NaN
# 2   LP002949  Female      No         3+      Graduate           NaN
# 3   LP002603  Female      No          0      Graduate            No
# 4   LP001644     NaN     Yes          0      Graduate           Yes
# 5   LP001259    Male     Yes          1      Graduate           Yes
# 6   LP002345    Male     Yes          0      Graduate            No
# 7   LP002717    Male     Yes          0      Graduate            No
# 8   LP001030    Male     Yes          2      Graduate            No
# 9   LP001267  Female     Yes          2      Graduate            No
# 10  LP001086    Male      No          0  Not Graduate            No
# 11  LP002287  Female      No          0      Graduate            No
# 12  LP001518    Male     Yes          1      Graduate            No
# ...

# %%
df1 = df[df['ApplicantIncome']<2000].count()
df1
# Out:
# Loan_ID              40
# Gender               39
# Married              40
# Dependents           40
# Education            40
# Self_Employed        37
# ApplicantIncome      40
# CoapplicantIncome    40
# LoanAmount           39
# Loan_Amount_Term     38
# Credit_History       35
# Property_Area        40
# Loan_Status          40
# dtype: int64

# %%
df2 = df[(df.ApplicantIncome<2000)&(df.Gender == 'Male')]
df2
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0   LP001722   Male     Yes          0      Graduate            No
# 5   LP001259   Male     Yes          1      Graduate           Yes
# 6   LP002345   Male     Yes          0      Graduate            No
# 7   LP002717   Male     Yes          0      Graduate            No
# 8   LP001030   Male     Yes          2      Graduate            No
# 10  LP001086   Male      No          0  Not Graduate            No
# 12  LP001518   Male     Yes          1      Graduate            No
# 13  LP002342   Male     Yes          2      Graduate           Yes
# 14  LP001977   Male     Yes          1      Graduate            No
# 15  LP001835   Male     Yes          0  Not Graduate            No
# 16  LP001343   Male     Yes          0      Graduate            No
# 17  LP002877   Male     Yes          1      Graduate            No
# 18  LP001120   Male      No          0      Graduate            No
# ...

# %%
df3 = df[(df.ApplicantIncome<2000)&(df.Gender == 'Male')].count()
df3
# Out:
# Loan_ID              29
# Gender               29
# Married              29
# Dependents           29
# Education            29
# Self_Employed        28
# ApplicantIncome      29
# CoapplicantIncome    29
# LoanAmount           29
# Loan_Amount_Term     28
# Credit_History       25
# Property_Area        29
# Loan_Status          29
# dtype: int64

# %% [markdown]
# ### It seems that there are the 29 memebers who are less than 2000 income of males

# %%
df2['ApplicantIncome'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df2.hist(color = 'k',bins = 30,figsize = (15,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.value_counts()
# Out:
# Loan_ID   Gender  Married  Dependents  Education     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# LP001003  Male    Yes      1           Graduate      No             4583             1508.0             128.0       360.0             1.0             Rural          N              1
# LP001005  Male    Yes      0           Graduate      Yes            3000             0.0                66.0        360.0             1.0             Urban          Y              1
# LP002347  Male    Yes      0           Graduate      No             3246             1417.0             138.0       360.0             1.0             Semiurban      Y              1
# LP002345  Male    Yes      0           Graduate      No             1025             2773.0             112.0       360.0             1.0             Rural          Y              1
# ...

# %%
df.CoapplicantIncome.mean()
# Out:
# 1621.245798027101

# %%
df.ApplicantIncome.mean()
# Out:
# 5403.459283387622

# %%
df4 = df.groupby('Self_Employed')[['ApplicantIncome']].sum()
df4
# Out:
#                ApplicantIncome
# Self_Employed
# No                     2524874
# Yes                     605227

# %% [markdown]
# ### It means that there are less employed people as per ApplicantIncome, lets see the analysis

# %%
df5 = pd.pivot_table(data = df,index =['Self_Employed'],values = ['ApplicantIncome'],aggfunc = 'sum',fill_value = 0,margins=0,margins_name = 'Total')
print(df5)
# Out:
#                ApplicantIncome
# Self_Employed
# No                     2524874
# Yes                     605227

# %%
df2 = df2.head(10)
df2.boxplot(column='ApplicantIncome',by =['CoapplicantIncome'])
plt.show()

# %%
df6 = df.head(10)
df6.boxplot(column='ApplicantIncome',by =['CoapplicantIncome'],figsize = (15,10))
plt.show()

# %%
df.describe(include = 'all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001722   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dropna()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001722    Male     Yes          0  Graduate            No
# 3    LP002603  Female      No          0  Graduate            No
# 5    LP001259    Male     Yes          1  Graduate           Yes
# 6    LP002345    Male     Yes          0  Graduate            No
# 8    LP001030    Male     Yes          2  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 607  LP001637    Male     Yes          1  Graduate            No
# 608  LP002422    Male      No          1  Graduate            No
# 609  LP001640    Male     Yes          0  Graduate           Yes
# 610  LP001536    Male     Yes         3+  Graduate            No
# 613  LP002317    Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
df.CoapplicantIncome.isnull().sum()
# Out:
# 0

# %%
df7 = df.groupby('Gender')[['ApplicantIncome','CoapplicantIncome']].agg('mean')
df7
# Out:
#         ApplicantIncome  CoapplicantIncome
# Gender
# Female      4643.473214        1108.008929
# Male        5446.460123        1742.932352

# %%
df.hist(color = 'k',bins = 20)
plt.show()

# %%
df_u = df.Property_Area.unique()
df_u
# Out:
# array(['Rural', 'Semiurban', 'Urban'], dtype=object)

# %%
df.groupby('Property_Area')[['ApplicantIncome','LoanAmount']].count()
# Out:
#                ApplicantIncome  LoanAmount
# Property_Area
# Rural                      179         173
# Semiurban                  233         228
# Urban                      202         191

# %%
df.groupby('Property_Area')[['ApplicantIncome','LoanAmount']].mean()
# Out:
#                ApplicantIncome  LoanAmount
# Property_Area
# Rural              5554.083799  152.260116
# Semiurban          5292.261803  145.504386
# Urban              5398.247525  142.198953
